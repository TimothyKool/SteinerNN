# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
import math
import csv
from tqdm import tqdm

# Load data
numInputs = 512
rowSize = 100
gridSize = 10000
x = np.zeros((numInputs, gridSize), dtype=np.float32)
y = np.zeros((numInputs, gridSize), dtype=np.float32)

with open("./smt100_ds11776/ps100_0_511.csv", "r") as f:
    reader = csv.reader(f, delimiter=",")
    it = int(0)
    for line in reader:
        # Empty row means that the set of points for the current graph
        # has ended. Update the iterator and continue
        if(len(line) == 0):
            it = it + 1
            continue
        # Skip over the starting row of each graph that only has the graph
        # number and number of steiner points
        if(len(line) == 2):
            continue
        # Coordinates of the current row
        row = int(line[1])
        column = int(line[2])
        # Fill in X and Y
        if(int(line[3]) == 0):
            x[it][rowSize*row + column] = -1.0
            y[it][rowSize*row + column] = -1.0
        else:
            y[it][rowSize*row + column] = 1.0

# %%
hidden_neurons = 1024
inputSize = 10000
outputSize = 10000
# Create model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(inputSize, hidden_neurons),
            nn.LeakyReLU(),
            nn.Linear(hidden_neurons, outputSize),
            nn.Hardtanh()
        )

    def forward(self, x):
        return self.layers(x)

# %%
# 60% 20% 20%
epochs = 20
model = Net()
my_loss = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1, momentum=0.9)
losses = []
for j in tqdm(range(epochs)):
    average_loss = 0
    for i in range(numInputs):
        x_tensor = torch.from_numpy(x[i])
        y_tensor = torch.from_numpy(y[i])
        # calls forward function on x_tensor
        output = model(x_tensor)

        loss = my_loss(output, y_tensor)
        average_loss += loss
        
        if i % 50 == 0:
            print(i, loss)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    average_loss = average_loss / 512
    losses.append(average_loss)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]0 tensor(0.0142, grad_fn=<MseLossBackward>)
# 50 tensor(0.0146, grad_fn=<MseLossBackward>)
# 100 tensor(0.0143, grad_fn=<MseLossBackward>)
# 150 tensor(0.0145, grad_fn=<MseLossBackward>)
# 200 tensor(0.0142, grad_fn=<MseLossBackward>)
# 250 tensor(0.0137, grad_fn=<MseLossBackward>)
# 300 tensor(0.0143, grad_fn=<MseLossBackward>)
# 350 tensor(0.0138, grad_fn=<MseLossBackward>)
# 400 tensor(0.0143, grad_fn=<MseLossBackward>)
# 450 tensor(0.0148, grad_fn=<MseLossBackward>)
# 500 tensor(0.0144, grad_fn=<MseLossBackward>)
#   5%|▌         | 1/20 [00:47<15:04, 47.60s/it]0 tensor(0.0138, grad_fn=<MseLossBackward>)
# 50 tensor(0.0142, grad_fn=<MseLossBackward>)
# 100 tensor(0.0138, grad_fn=<MseLossBackward>)
# 150 tensor(0.0141, grad_fn=<MseLossBackward>)
# 200 tensor(0.0138, grad_fn=<MseLossBackward>)
# 250 tensor(0.0134, grad_fn=<MseLossBackward>)
# 300 tensor(0.0140, grad_fn=<MseLossBackward>)
# 350 tensor(0.0135, grad_fn=<MseLossBackward>)
# 400 tensor(0.0140, grad_fn=<MseLossBackward>)
# 450 tensor(0.0145, grad_fn=<MseLossBackward>)
# 500 tensor(0.0141, grad_fn=<MseLossBackward>)
#  10%|█         | 2/20 [01:31<13:56, 46.46s/it]0 tensor(0.0136, grad_fn=<MseLossBackward>)
# 50 tensor(0.0140, grad_fn=<MseLossBackward>)
# 100 tensor(0.0136, grad_fn=<MseLossBackward>)
# 150 tensor(0.0139, grad_fn=<MseLossBackward>)
# 200 tensor(0.0136, grad_fn=<MseLossBackward>)
# 250 tensor(0.0132, grad_fn=<MseLossBackward>)
# 300 tensor(0.0138, grad_fn=<MseLossBackward>)
# 350 tensor(0.0133, grad_fn=<MseLossBackward>)
# 400 tensor(0.0138, grad_fn=<MseLossBackward>)
# 450 tensor(0.0143, grad_fn=<MseLossBackward>)
# 500 tensor(0.0140, grad_fn=<MseLossBackward>)
#  15%|█▌        | 3/20 [02:16<13:05, 46.18s/it]0 tensor(0.0134, grad_fn=<MseLossBackward>)
# 50 tensor(0.0139, grad_fn=<MseLossBackward>)
# 100 tensor(0.0135, grad_fn=<MseLossBackward>)
# 150 tensor(0.0138, grad_fn=<MseLossBackward>)
# 200 tensor(0.0135, grad_fn=<MseLossBackward>)
# 250 tensor(0.0130, grad_fn=<MseLossBackward>)
# 300 tensor(0.0137, grad_fn=<MseLossBackward>)
# 350 tensor(0.0132, grad_fn=<MseLossBackward>)
# 400 tensor(0.0137, grad_fn=<MseLossBackward>)
# 450 tensor(0.0142, grad_fn=<MseLossBackward>)
# 500 tensor(0.0139, grad_fn=<MseLossBackward>)
#  20%|██        | 4/20 [03:04<12:27, 46.70s/it]0 tensor(0.0133, grad_fn=<MseLossBackward>)
# 50 tensor(0.0138, grad_fn=<MseLossBackward>)
# 100 tensor(0.0134, grad_fn=<MseLossBackward>)
# 150 tensor(0.0137, grad_fn=<MseLossBackward>)
# 200 tensor(0.0134, grad_fn=<MseLossBackward>)
# 250 tensor(0.0129, grad_fn=<MseLossBackward>)
# 300 tensor(0.0136, grad_fn=<MseLossBackward>)
# 350 tensor(0.0131, grad_fn=<MseLossBackward>)
# 400 tensor(0.0136, grad_fn=<MseLossBackward>)
# 450 tensor(0.0141, grad_fn=<MseLossBackward>)
# 500 tensor(0.0138, grad_fn=<MseLossBackward>)
#  25%|██▌       | 5/20 [03:54<11:54, 47.62s/it]0 tensor(0.0133, grad_fn=<MseLossBackward>)
# 50 tensor(0.0137, grad_fn=<MseLossBackward>)
# 100 tensor(0.0133, grad_fn=<MseLossBackward>)
# 150 tensor(0.0136, grad_fn=<MseLossBackward>)
# 200 tensor(0.0133, grad_fn=<MseLossBackward>)
# 250 tensor(0.0129, grad_fn=<MseLossBackward>)
# 300 tensor(0.0135, grad_fn=<MseLossBackward>)
# 350 tensor(0.0131, grad_fn=<MseLossBackward>)
# 400 tensor(0.0135, grad_fn=<MseLossBackward>)
# 450 tensor(0.0140, grad_fn=<MseLossBackward>)
# 500 tensor(0.0137, grad_fn=<MseLossBackward>)
#  30%|███       | 6/20 [04:43<11:12, 48.01s/it]0 tensor(0.0132, grad_fn=<MseLossBackward>)
# 50 tensor(0.0137, grad_fn=<MseLossBackward>)
# 100 tensor(0.0133, grad_fn=<MseLossBackward>)
# 150 tensor(0.0136, grad_fn=<MseLossBackward>)
# 200 tensor(0.0133, grad_fn=<MseLossBackward>)
# 250 tensor(0.0128, grad_fn=<MseLossBackward>)
# 300 tensor(0.0135, grad_fn=<MseLossBackward>)
# 350 tensor(0.0130, grad_fn=<MseLossBackward>)
# 400 tensor(0.0135, grad_fn=<MseLossBackward>)
# 450 tensor(0.0140, grad_fn=<MseLossBackward>)
# 500 tensor(0.0136, grad_fn=<MseLossBackward>)
#  35%|███▌      | 7/20 [05:29<10:17, 47.48s/it]0 tensor(0.0131, grad_fn=<MseLossBackward>)
# 50 tensor(0.0136, grad_fn=<MseLossBackward>)
# 100 tensor(0.0132, grad_fn=<MseLossBackward>)
# 150 tensor(0.0135, grad_fn=<MseLossBackward>)
# 200 tensor(0.0132, grad_fn=<MseLossBackward>)
# 250 tensor(0.0128, grad_fn=<MseLossBackward>)
# 300 tensor(0.0134, grad_fn=<MseLossBackward>)
# 350 tensor(0.0129, grad_fn=<MseLossBackward>)
# 400 tensor(0.0134, grad_fn=<MseLossBackward>)
# 450 tensor(0.0139, grad_fn=<MseLossBackward>)
# 500 tensor(0.0136, grad_fn=<MseLossBackward>)
#  40%|████      | 8/20 [06:10<09:05, 45.44s/it]0 tensor(0.0131, grad_fn=<MseLossBackward>)
# 50 tensor(0.0136, grad_fn=<MseLossBackward>)
# 100 tensor(0.0132, grad_fn=<MseLossBackward>)
# 150 tensor(0.0135, grad_fn=<MseLossBackward>)
# 200 tensor(0.0132, grad_fn=<MseLossBackward>)
# 250 tensor(0.0127, grad_fn=<MseLossBackward>)
# 300 tensor(0.0134, grad_fn=<MseLossBackward>)
# 350 tensor(0.0129, grad_fn=<MseLossBackward>)
# 400 tensor(0.0134, grad_fn=<MseLossBackward>)
# 450 tensor(0.0139, grad_fn=<MseLossBackward>)
# 500 tensor(0.0136, grad_fn=<MseLossBackward>)
#  45%|████▌     | 9/20 [06:51<08:04, 44.05s/it]0 tensor(0.0131, grad_fn=<MseLossBackward>)
# 50 tensor(0.0136, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0134, grad_fn=<MseLossBackward>)
# 200 tensor(0.0132, grad_fn=<MseLossBackward>)
# 250 tensor(0.0127, grad_fn=<MseLossBackward>)
# 300 tensor(0.0134, grad_fn=<MseLossBackward>)
# 350 tensor(0.0129, grad_fn=<MseLossBackward>)
# 400 tensor(0.0134, grad_fn=<MseLossBackward>)
# 450 tensor(0.0139, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  50%|█████     | 10/20 [07:34<07:16, 43.67s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0135, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0134, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0127, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  55%|█████▌    | 11/20 [08:19<06:38, 44.22s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0135, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0134, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  60%|██████    | 12/20 [09:05<05:58, 44.85s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0135, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  65%|██████▌   | 13/20 [09:52<05:17, 45.39s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0135, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  70%|███████   | 14/20 [10:41<04:38, 46.36s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  75%|███████▌  | 15/20 [11:26<03:50, 46.02s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  80%|████████  | 16/20 [12:11<03:03, 45.81s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  85%|████████▌ | 17/20 [12:56<02:16, 45.46s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0132, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  90%|█████████ | 18/20 [13:42<01:31, 45.61s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0132, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0133, grad_fn=<MseLossBackward>)
#  95%|█████████▌| 19/20 [14:28<00:45, 45.86s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0132, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0133, grad_fn=<MseLossBackward>)
# 100%|██████████| 20/20 [15:15<00:00, 45.77s/it]

# %%
# Load in new data set
testInputs = 512
originalPoints = np.zeros(512)
x_test = np.zeros((testInputs, gridSize), dtype=np.float32)
y_test = np.zeros((testInputs, gridSize), dtype=np.float32)

with open("./smt100_ds11776/ps100_512_1023.csv", "r") as f:
    reader = csv.reader(f, delimiter=",")
    it = int(0)
    for line in reader:
        # Empty row means that the set of points for the current graph
        # has ended. Update the iterator and continue
        if(len(line) == 0):
            it = it + 1
            continue
        # Skip over the starting row of each graph that only has the graph
        # number and number of steiner points
        if(len(line) == 2):
            originalPoints[it] = line[1]
            continue
        # Coordinates of the current row
        row = int(line[1])
        column = int(line[2])
        # Fill in X and Y
        if(int(line[3]) == 0):
            x_test[it][rowSize*row + column] = -1.0
            y_test[it][rowSize*row + column] = -1.0
        else:
            y_test[it][rowSize*row + column] = 1.0

# %%
# Evaluate model
missedPoints = 0
numSteinerPoints = 0
accuracy = 0.0
for i in range(numInputs):
    x_tensor = torch.from_numpy(x_test[i])
    y_tensor = torch.from_numpy(y_test[i])
    # calls forward function on x_tensor
    output = model(x_tensor)
    output = output * 10
    y_pred = torch.round(output)
    # print("should be close to -1", output[3*100+17])
    # if i == 0:
    #     for num in output:
    #         print(num)

    y_pred[y_pred<0.001] = 0
    y_tensor[y_tensor<0.001] = 0
    y_pred = y_pred.type(torch.int)
    y_tensor = y_tensor.type(torch.int)
    # print(torch.bincount(y_pred))
    # print(torch.bincount(y_tensor))

    # 100 * number of missed original steiner points / number of original steiner points
    diff = y_tensor - y_pred
    # y_pred = y_pred.type(torch.int)
    # y_tensor = y_tensor.type(torch.int)
    # Only want 1s in diff
    diff[diff < 0.001] = 0
    diff = diff.type(torch.int)
    missedPoints = torch.bincount(diff)[1]
    numSteinerPoints = originalPoints[i]
    accuracy += (numSteinerPoints - missedPoints) / numSteinerPoints
accuracy = 100 * accuracy / numInputs

# %%
print(accuracy)
# Out:
# tensor(0.0602)
