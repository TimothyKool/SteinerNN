# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
import math
import csv
from tqdm import tqdm

# Load data
numInputs = 512
rowSize = 100
gridSize = 10000
x = np.zeros((numInputs, gridSize), dtype=np.float32)
y = np.zeros((numInputs, gridSize), dtype=np.float32)

with open("./smt100_ds11776/ps100_0_511.csv", "r") as f:
    reader = csv.reader(f, delimiter=",")
    it = int(0)
    for line in reader:
        # Empty row means that the set of points for the current graph
        # has ended. Update the iterator and continue
        if(len(line) == 0):
            it = it + 1
            continue
        # Skip over the starting row of each graph that only has the graph
        # number and number of steiner points
        if(len(line) == 2):
            continue
        # Coordinates of the current row
        row = int(line[1])
        column = int(line[2])
        # Fill in X and Y
        if(int(line[3]) == 0):
            x[it][rowSize*row + column] = -1.0
            y[it][rowSize*row + column] = -1.0
        else:
            y[it][rowSize*row + column] = 1.0

# %%
hidden_neurons = 1024
inputSize = 10000
outputSize = 10000
# Create model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(inputSize, hidden_neurons),
            nn.LeakyReLU(),
            nn.Linear(hidden_neurons, outputSize),
            nn.Hardtanh()
        )

    def forward(self, x):
        return self.layers(x)

# %%
# 60% 20% 20%
epochs = 20
model = Net()
my_loss = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1, momentum=0.9)
for j in tqdm(range(epochs)):
    for i in range(numInputs):
        x_tensor = torch.from_numpy(x[i])
        y_tensor = torch.from_numpy(y[i])
        # calls forward function on x_tensor
        output = model(x_tensor)

        loss = my_loss(output, y_tensor)
        
        if i % 50 == 0:
            print(i, loss)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]0 tensor(0.0143, grad_fn=<MseLossBackward>)
# 50 tensor(0.0148, grad_fn=<MseLossBackward>)
# 100 tensor(0.0143, grad_fn=<MseLossBackward>)
# 150 tensor(0.0145, grad_fn=<MseLossBackward>)
# 200 tensor(0.0142, grad_fn=<MseLossBackward>)
# 250 tensor(0.0135, grad_fn=<MseLossBackward>)
# 300 tensor(0.0143, grad_fn=<MseLossBackward>)
# 350 tensor(0.0138, grad_fn=<MseLossBackward>)
# 400 tensor(0.0143, grad_fn=<MseLossBackward>)
# 450 tensor(0.0148, grad_fn=<MseLossBackward>)
# 500 tensor(0.0144, grad_fn=<MseLossBackward>)
#   5%|▌         | 1/20 [00:46<14:50, 46.85s/it]0 tensor(0.0138, grad_fn=<MseLossBackward>)
# 50 tensor(0.0143, grad_fn=<MseLossBackward>)
# 100 tensor(0.0139, grad_fn=<MseLossBackward>)
# 150 tensor(0.0141, grad_fn=<MseLossBackward>)
# 200 tensor(0.0138, grad_fn=<MseLossBackward>)
# 250 tensor(0.0132, grad_fn=<MseLossBackward>)
# 300 tensor(0.0140, grad_fn=<MseLossBackward>)
# 350 tensor(0.0135, grad_fn=<MseLossBackward>)
# 400 tensor(0.0140, grad_fn=<MseLossBackward>)
# 450 tensor(0.0145, grad_fn=<MseLossBackward>)
# 500 tensor(0.0142, grad_fn=<MseLossBackward>)
#  10%|█         | 2/20 [01:32<13:57, 46.52s/it]0 tensor(0.0136, grad_fn=<MseLossBackward>)
# 50 tensor(0.0141, grad_fn=<MseLossBackward>)
# 100 tensor(0.0136, grad_fn=<MseLossBackward>)
# 150 tensor(0.0139, grad_fn=<MseLossBackward>)
# 200 tensor(0.0136, grad_fn=<MseLossBackward>)
# 250 tensor(0.0131, grad_fn=<MseLossBackward>)
# 300 tensor(0.0138, grad_fn=<MseLossBackward>)
# 350 tensor(0.0133, grad_fn=<MseLossBackward>)
# 400 tensor(0.0138, grad_fn=<MseLossBackward>)
# 450 tensor(0.0143, grad_fn=<MseLossBackward>)
# 500 tensor(0.0140, grad_fn=<MseLossBackward>)
#  15%|█▌        | 3/20 [02:18<13:07, 46.34s/it]0 tensor(0.0135, grad_fn=<MseLossBackward>)
# 50 tensor(0.0139, grad_fn=<MseLossBackward>)
# 100 tensor(0.0135, grad_fn=<MseLossBackward>)
# 150 tensor(0.0138, grad_fn=<MseLossBackward>)
# 200 tensor(0.0135, grad_fn=<MseLossBackward>)
# 250 tensor(0.0130, grad_fn=<MseLossBackward>)
# 300 tensor(0.0137, grad_fn=<MseLossBackward>)
# 350 tensor(0.0132, grad_fn=<MseLossBackward>)
# 400 tensor(0.0137, grad_fn=<MseLossBackward>)
# 450 tensor(0.0142, grad_fn=<MseLossBackward>)
# 500 tensor(0.0139, grad_fn=<MseLossBackward>)
#  20%|██        | 4/20 [03:05<12:23, 46.44s/it]0 tensor(0.0134, grad_fn=<MseLossBackward>)
# 50 tensor(0.0138, grad_fn=<MseLossBackward>)
# 100 tensor(0.0134, grad_fn=<MseLossBackward>)
# 150 tensor(0.0137, grad_fn=<MseLossBackward>)
# 200 tensor(0.0134, grad_fn=<MseLossBackward>)
# 250 tensor(0.0129, grad_fn=<MseLossBackward>)
# 300 tensor(0.0136, grad_fn=<MseLossBackward>)
# 350 tensor(0.0131, grad_fn=<MseLossBackward>)
# 400 tensor(0.0136, grad_fn=<MseLossBackward>)
# 450 tensor(0.0141, grad_fn=<MseLossBackward>)
# 500 tensor(0.0138, grad_fn=<MseLossBackward>)
#  25%|██▌       | 5/20 [03:52<11:39, 46.63s/it]0 tensor(0.0133, grad_fn=<MseLossBackward>)
# 50 tensor(0.0137, grad_fn=<MseLossBackward>)
# 100 tensor(0.0133, grad_fn=<MseLossBackward>)
# 150 tensor(0.0136, grad_fn=<MseLossBackward>)
# 200 tensor(0.0133, grad_fn=<MseLossBackward>)
# 250 tensor(0.0128, grad_fn=<MseLossBackward>)
# 300 tensor(0.0135, grad_fn=<MseLossBackward>)
# 350 tensor(0.0130, grad_fn=<MseLossBackward>)
# 400 tensor(0.0135, grad_fn=<MseLossBackward>)
# 450 tensor(0.0140, grad_fn=<MseLossBackward>)
# 500 tensor(0.0137, grad_fn=<MseLossBackward>)
#  30%|███       | 6/20 [04:39<10:56, 46.93s/it]0 tensor(0.0132, grad_fn=<MseLossBackward>)
# 50 tensor(0.0137, grad_fn=<MseLossBackward>)
# 100 tensor(0.0133, grad_fn=<MseLossBackward>)
# 150 tensor(0.0136, grad_fn=<MseLossBackward>)
# 200 tensor(0.0133, grad_fn=<MseLossBackward>)
# 250 tensor(0.0127, grad_fn=<MseLossBackward>)
# 300 tensor(0.0135, grad_fn=<MseLossBackward>)
# 350 tensor(0.0129, grad_fn=<MseLossBackward>)
# 400 tensor(0.0134, grad_fn=<MseLossBackward>)
# 450 tensor(0.0140, grad_fn=<MseLossBackward>)
# 500 tensor(0.0137, grad_fn=<MseLossBackward>)
#  35%|███▌      | 7/20 [05:26<10:08, 46.84s/it]0 tensor(0.0132, grad_fn=<MseLossBackward>)
# 50 tensor(0.0136, grad_fn=<MseLossBackward>)
# 100 tensor(0.0132, grad_fn=<MseLossBackward>)
# 150 tensor(0.0135, grad_fn=<MseLossBackward>)
# 200 tensor(0.0132, grad_fn=<MseLossBackward>)
# 250 tensor(0.0127, grad_fn=<MseLossBackward>)
# 300 tensor(0.0134, grad_fn=<MseLossBackward>)
# 350 tensor(0.0129, grad_fn=<MseLossBackward>)
# 400 tensor(0.0134, grad_fn=<MseLossBackward>)
# 450 tensor(0.0139, grad_fn=<MseLossBackward>)
# 500 tensor(0.0136, grad_fn=<MseLossBackward>)
#  40%|████      | 8/20 [06:15<09:29, 47.49s/it]0 tensor(0.0131, grad_fn=<MseLossBackward>)
# 50 tensor(0.0135, grad_fn=<MseLossBackward>)
# 100 tensor(0.0132, grad_fn=<MseLossBackward>)
# 150 tensor(0.0135, grad_fn=<MseLossBackward>)
# 200 tensor(0.0132, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0134, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0134, grad_fn=<MseLossBackward>)
# 450 tensor(0.0139, grad_fn=<MseLossBackward>)
# 500 tensor(0.0136, grad_fn=<MseLossBackward>)
#  45%|████▌     | 9/20 [07:04<08:45, 47.78s/it]0 tensor(0.0131, grad_fn=<MseLossBackward>)
# 50 tensor(0.0135, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0134, grad_fn=<MseLossBackward>)
# 200 tensor(0.0132, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0136, grad_fn=<MseLossBackward>)
#  50%|█████     | 10/20 [07:48<07:47, 46.80s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0135, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0134, grad_fn=<MseLossBackward>)
# 200 tensor(0.0132, grad_fn=<MseLossBackward>)
# 250 tensor(0.0126, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  55%|█████▌    | 11/20 [08:35<07:01, 46.81s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0131, grad_fn=<MseLossBackward>)
# 150 tensor(0.0134, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0128, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  60%|██████    | 12/20 [09:24<06:20, 47.57s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0134, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0133, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  65%|██████▌   | 13/20 [10:12<05:33, 47.67s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0133, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0138, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  70%|███████   | 14/20 [11:00<04:45, 47.66s/it]0 tensor(0.0130, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  75%|███████▌  | 15/20 [11:49<04:00, 48.14s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0125, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0135, grad_fn=<MseLossBackward>)
#  80%|████████  | 16/20 [12:36<03:10, 47.68s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0133, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0131, grad_fn=<MseLossBackward>)
# 250 tensor(0.0124, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  85%|████████▌ | 17/20 [13:22<02:21, 47.29s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0133, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0124, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  90%|█████████ | 18/20 [14:08<01:33, 46.80s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0133, grad_fn=<MseLossBackward>)
# 100 tensor(0.0130, grad_fn=<MseLossBackward>)
# 150 tensor(0.0133, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0124, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0127, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
#  95%|█████████▌| 19/20 [14:52<00:46, 46.19s/it]0 tensor(0.0129, grad_fn=<MseLossBackward>)
# 50 tensor(0.0133, grad_fn=<MseLossBackward>)
# 100 tensor(0.0129, grad_fn=<MseLossBackward>)
# 150 tensor(0.0132, grad_fn=<MseLossBackward>)
# 200 tensor(0.0130, grad_fn=<MseLossBackward>)
# 250 tensor(0.0124, grad_fn=<MseLossBackward>)
# 300 tensor(0.0132, grad_fn=<MseLossBackward>)
# 350 tensor(0.0126, grad_fn=<MseLossBackward>)
# 400 tensor(0.0132, grad_fn=<MseLossBackward>)
# 450 tensor(0.0137, grad_fn=<MseLossBackward>)
# 500 tensor(0.0134, grad_fn=<MseLossBackward>)
# 100%|██████████| 20/20 [15:37<00:00, 46.88s/it]

# %%
# Load in new data set
testInputs = 512
originalPoints = np.zeros(512)
x_test = np.zeros((testInputs, gridSize), dtype=np.float32)
y_test = np.zeros((testInputs, gridSize), dtype=np.float32)

with open("./smt100_ds11776/ps100_512_1023.csv", "r") as f:
    reader = csv.reader(f, delimiter=",")
    it = int(0)
    for line in reader:
        # Empty row means that the set of points for the current graph
        # has ended. Update the iterator and continue
        if(len(line) == 0):
            it = it + 1
            continue
        # Skip over the starting row of each graph that only has the graph
        # number and number of steiner points
        if(len(line) == 2):
            originalPoints[it] = line[1]
            continue
        # Coordinates of the current row
        row = int(line[1])
        column = int(line[2])
        # Fill in X and Y
        if(int(line[3]) == 0):
            x_test[it][rowSize*row + column] = -1.0
            y_test[it][rowSize*row + column] = -1.0
        else:
            y_test[it][rowSize*row + column] = 1.0

# %%
# Evaluate model
missedPoints = 0
numSteinerPoints = 0
accuracy = 0.0
for i in range(numInputs):
    x_tensor = torch.from_numpy(x_test[i])
    y_tensor = torch.from_numpy(y_test[i])
    # calls forward function on x_tensor
    output = model(x_tensor)
    y_pred = torch.round(output)

    y_pred[y_pred<0.001] = 0
    y_tensor[y_tensor<0.001] = 0
    print(torch.bincount(y_pred))
    print(torch.bincount(y_tensor))

    # 100 * number of missed original steiner points / number of original steiner points
    diff = y_tensor - y_pred
    # y_pred = y_pred.type(torch.int)
    # y_tensor = y_tensor.type(torch.int)
    # Only want 1s in diff
    diff[diff < 0.001] = 0
    diff = diff.type(torch.int)
    missedPoints = torch.bincount(diff)[1]
    numSteinerPoints = originalPoints[i]
    accuracy += missedPoints / numSteinerPoints
accuracy = accuracy / numInputs
# Out:
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(29)
# Steiner Points:  29.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(28)
# Steiner Points:  28.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(45)
# Steiner Points:  45.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(29)
# Steiner Points:  29.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(28)
# Steiner Points:  28.0
# Missed Points:  tensor(28)
# Steiner Points:  28.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(29)
# Steiner Points:  29.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(28)
# Steiner Points:  28.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(29)
# Steiner Points:  29.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(27)
# Steiner Points:  27.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(45)
# Steiner Points:  45.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(44)
# Steiner Points:  44.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(45)
# Steiner Points:  45.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(43)
# Steiner Points:  43.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(31)
# Steiner Points:  31.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(27)
# Steiner Points:  27.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(40)
# Steiner Points:  40.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(41)
# Steiner Points:  41.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(34)
# Steiner Points:  34.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(37)
# Steiner Points:  37.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(39)
# Steiner Points:  39.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(33)
# Steiner Points:  33.0
# Missed Points:  tensor(42)
# Steiner Points:  42.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(30)
# Steiner Points:  30.0
# Missed Points:  tensor(32)
# Steiner Points:  32.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(35)
# Steiner Points:  35.0
# Missed Points:  tensor(36)
# Steiner Points:  36.0
# Missed Points:  tensor(28)
# Steiner Points:  28.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0
# Missed Points:  tensor(38)
# Steiner Points:  38.0

# %%
print(accuracy)
# Out:
# tensor(1.)

# %%
test = torch.tensor([.1, .2, .8, -.7])
test = torch.round(test)
test = test.type(torch.int)
print(test)
# Out:
# tensor([ 0,  0,  1, -1], dtype=torch.int32)
